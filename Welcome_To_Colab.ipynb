# %% [markdown]
# <a href="https://colab.research.google.com/github/Hebaade/ML-Models/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 115.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="jNidOrV5Xb30L6QlrfGd")
project = rf.workspace("mohamed-traore-2ekkp").project("face-detection-mik1i")
version = project.version(27)
dataset = version.download("yolov12")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Face-Detection-27 in yolov12:: 100%|██████████| 390/390 [00:00<00:00, 5547.87it/s]

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/112.6 GB disk)

# %%
from ultralytics import YOLO
## Load a COCO-pretrained YOLO12n model
model = YOLO("yolo12n.pt")

## Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="/content/Face-Detection-27/data.yaml", epochs=20, imgsz=640,batch=16)
# Out:
# ...
# 100%|██████████| 5.34M/5.34M [00:00<00:00, 103MB/s]
# Ultralytics 8.3.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image, display

# %%
display(Image(filename=f"/content/runs/detect/train/results.png", width=1000))

# %%
display(Image(filename=f"/content/runs/detect/train/confusion_matrix.png", width=1000))

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")  # load a custom model

## Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics 8.3.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12n summary (fused): 159 layers, 2,556,923 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/Face-Detection-27/valid/labels.cache... 38 images, 1 backgrounds, 0 corrupt: 100%|██████████| 38/38 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:01<00:00,  1.58it/s]
#                    all         38         49      0.888      0.918      0.947      0.697
# Speed: 5.0ms preprocess, 15.7ms inference, 0.1ms loss, 2.3ms postprocess per image
# Results saved to runs/detect/val
# array([    0.69733])

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt imgsz=640 conf=0.5 \
source=/content/Face-Detection-27/test/images
# Out:
# Ultralytics 8.3.103 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12n summary (fused): 159 layers, 2,556,923 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/19 /content/Face-Detection-27/test/images/Movie-on-2-18-25-at-8_25-PM_mov-0000_jpg.rf.b8844c6c867798aa5992c180730a9198.jpg: 448x640 1 face, 58.8ms
# image 2/19 /content/Face-Detection-27/test/images/Movie-on-2-18-25-at-8_25-PM_mov-0002_jpg.rf.060944fbbd666495bdbea8d2fa9e2d01.jpg: 448x640 1 face, 14.9ms
# image 3/19 /content/Face-Detection-27/test/images/Movie-on-2-18-25-at-8_25-PM_mov-0014_jpg.rf.7f25b9d29aa91b409397e8fa28709ef4.jpg: 448x640 1 face, 13.9ms
# image 4/19 /content/Face-Detection-27/test/images/Movie-on-2-18-25-at-8_25-PM_mov-0053_jpg.rf.9a73888ffd9aad89d0217452c9662e73.jpg: 448x640 2 faces, 14.0ms
# image 5/19 /content/Face-Detection-27/test/images/Movie-on-2-18-25-at-8_25-PM_mov-0055_jpg.rf.0dd9c7cee88e943cb8c88e9b3c4bfbdf.jpg: 448x640 2 faces, 13.7ms
# ...

# %%
# Display inference on ALL test images
import glob
from IPython.display import Image, display
i = 0
for imageName in glob.glob("runs/detect/predict/*.jpg"): #assuming JPG
    if i %20 == 0 :
        print("\n")
        display(Image(filename=imageName))
    i = i +1
